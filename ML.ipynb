# %%
#https://www.youtube.com/watch?v=0irmDBWLrco
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score
import pandas as pd
PL = pd.read_csv('PL.csv', low_memory = False)
PL.shape
# Out:
# (3040, 34)

# %%
train = PL[PL.DATE <= '2023-08-01']
test =  PL[PL.DATE > '2023-08-01']
print( train.shape, test.shape)
# Out:
# (2280, 34) (760, 34)

# %%
rf = RandomForestClassifier(n_estimators = 50, min_samples_split = 10, random_state = 1)
predictors = ['VENUE_CD', 'OPPONENT_CD', 'DAY_CD']
rf.fit(train[predictors], train['TARGET'])
preds = rf.predict(test[predictors])

# %%
acc = accuracy_score(test['TARGET'], preds)
acc
# Out:
# 0.6381578947368421

# %%
combined = pd.DataFrame(dict(actual=test.TARGET, prediction = preds))
# Crosstab
pd.crosstab(index = combined ['actual'], columns = combined['prediction'])
# This method predicts from accurately the loss/draw not the win
# Out:
# prediction    0   1
# actual
# 0           412  91
# 1           184  73

# %%
prec = precision_score(test['TARGET'], preds)
prec
# Out:
# 0.4451219512195122

# %%
grouped_matches = PL.groupby('TEAM')
group = grouped_matches.get_group('Liverpool')

# %%
def rolling_avergs(group, cols, new_cols):
    group = group.sort_values(by = 'DATE')
    rollins_stats = group[cols].rolling(3, closed = 'left').mean()
    group[new_cols] = rollins_stats
    group = group.dropna(subset = new_cols)
    return group

# %%
cols = ['GF', 'GA', 'SH', 'SOT', 'DIST', 'FK', 'PK', 'PKATT']
new_cols = [f'{c}_rolling' for c in cols]
PL_rolling = PL.groupby('TEAM').apply(lambda x: rolling_avergs(x, cols, new_cols))
PL_rolling = PL_rolling.droplevel('TEAM').reset_index(drop = True)
PL_rolling
# Out:
# /var/folders/dg/fckc2gz96c599j8pqfzz6jzr0000gn/T/ipykernel_1346/478837465.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   PL_rolling = PL.groupby('TEAM').apply(lambda x: rolling_avergs(x, cols, new_cols))
#             DATE   TIME            COMP         ROUND  DAY VENUE RESULT   GF  \
# 0     2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 1     2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 2     2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 3     2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 4     2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ...          ...    ...             ...           ...  ...   ...    ...  ...
# 2875  2024-04-02  19:45  Premier League  Matchweek 31  Tue  Away      D  1.0
# 2876  2024-04-06  15:00  Premier League  Matchweek 32  Sat  Home      L  1.0
# 2877  2024-04-13  15:00  Premier League  Matchweek 33  Sat  Away      D  2.0
# 2878  2024-04-20  19:30  Premier League  Matchweek 34  Sat  Home      L  0.0
# 2879  2024-04-24  19:45  Premier League  Matchweek 29  Wed  Home    NaN  NaN
#
#        GA         OPPONENT  ...  TARGET  TARGET2  GF_rolling  GA_rolling  \
# 0     1.0    Sheffield Utd  ...       1        2    2.000000    1.333333
# 1     1.0  Manchester City  ...       0        0    1.666667    1.666667
# 2     1.0   Leicester City  ...       0        0    1.000000    1.666667
# 3     0.0   Manchester Utd  ...       1        2    0.666667    1.000000
# 4     3.0      Aston Villa  ...       0        0    0.333333    0.666667
# ...   ...              ...  ...     ...      ...         ...         ...
# 2875  1.0          Burnley  ...       0        1    0.666667    2.000000
# 2876  2.0         West Ham  ...       0        0    1.000000    1.333333
# 2877  2.0  Nott'ham Forest  ...       0        1    0.666667    1.666667
# 2878  2.0          Arsenal  ...       0        0    1.333333    1.666667
# 2879  NaN      Bournemouth  ...       0        0    1.000000    2.000000
#
#      SH_rolling SOT_rolling DIST_rolling FK_rolling  PK_rolling  PKATT_rolling
# 0      8.000000    3.666667    14.633333   0.666667    0.000000       0.000000
# 1      5.666667    3.666667    15.366667   0.000000    0.000000       0.000000
# 2      7.000000    3.666667    16.566667   0.666667    0.000000       0.000000
# 3      9.666667    4.000000    16.566667   1.000000    0.000000       0.000000
# 4      9.666667    2.666667    19.333333   1.000000    0.333333       0.333333
# ...         ...         ...          ...        ...         ...            ...
# 2875  11.000000    3.000000    15.600000   0.333333    0.000000       0.000000
# 2876   9.666667    2.666667    14.433333   0.333333    0.000000       0.000000
# 2877  11.333333    3.666667    17.466667   0.666667    0.333333       0.333333
# 2878  10.666667    3.666667    17.966667   0.333333    0.333333       0.333333
# 2879   9.666667    4.000000    20.533333   0.333333    0.333333       0.333333
#
# [2880 rows x 42 columns]

# %%
def make_predictions(data, predictors, target = 'TARGET'):
    datel = '2022-01-01'
    test =  data[data.DATE > datel]
    train = data[data.DATE <= datel]
    rf = RandomForestClassifier(criterion = 'entropy', n_estimators = 50, min_samples_split = 10, random_state = 1)
    rf.fit(train[predictors], train[target])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test[target], prediction = preds), index = test.index)
    precision = precision_score(test[target], preds, average = 'weighted')
    return combined, precision

# %%
combined, precision = make_predictions (PL_rolling[(PL_rolling.DATE > '2021-08-01') & (PL_rolling.DATE < '2023-01-01')], predictors + new_cols)
precision
# Out:
# 0.5828302430116235

# %%
combined
# Out:
#       actual  prediction
# 55         0           0
# 56         1           0
# 57         1           0
# 58         1           0
# 59         1           1
# ...      ...         ...
# 2820       0           0
# 2821       0           0
# 2822       0           0
# 2823       1           0
# 2824       0           0
#
# [710 rows x 2 columns]

# %%
combined = combined.merge(PL_rolling[['DATE', 'TEAM', 'OPPONENT', 'RESULT']], left_index = True, right_index = True)
combined
# Out:
#       actual  prediction        DATE     TEAM        OPPONENT RESULT
# 55         0           0  2022-01-23  Arsenal         Burnley      D
# 56         1           0  2022-02-10  Arsenal          Wolves      W
# 57         1           0  2022-02-19  Arsenal       Brentford      W
# 58         1           0  2022-02-24  Arsenal          Wolves      W
# 59         1           1  2022-03-06  Arsenal         Watford      W
# ...      ...         ...         ...      ...             ...    ...
# 2820       0           0  2022-10-29   Wolves       Brentford      D
# 2821       0           0  2022-11-05   Wolves        Brighton      L
# 2822       0           0  2022-11-12   Wolves         Arsenal      L
# 2823       1           0  2022-12-26   Wolves         Everton      W
# 2824       0           0  2022-12-31   Wolves  Manchester Utd      L
#
# [710 rows x 6 columns]

# %%
merged = combined.merge(combined, left_on = ['DATE', "TEAM"], right_on = ['DATE', 'OPPONENT'])
merged
# Out:
#      actual_x  prediction_x        DATE   TEAM_x      OPPONENT_x RESULT_x  \
# 0           0             0  2022-01-23  Arsenal         Burnley        D
# 1           1             0  2022-02-10  Arsenal          Wolves        W
# 2           1             0  2022-02-19  Arsenal       Brentford        W
# 3           1             0  2022-02-24  Arsenal          Wolves        W
# 4           1             1  2022-03-06  Arsenal         Watford        W
# ..        ...           ...         ...      ...             ...      ...
# 699         0             0  2022-10-29   Wolves       Brentford        D
# 700         0             0  2022-11-05   Wolves        Brighton        L
# 701         0             0  2022-11-12   Wolves         Arsenal        L
# 702         1             0  2022-12-26   Wolves         Everton        W
# 703         0             0  2022-12-31   Wolves  Manchester Utd        L
#
#      actual_y  prediction_y          TEAM_y OPPONENT_y RESULT_y
# 0           0             0         Burnley    Arsenal        D
# 1           0             0          Wolves    Arsenal        L
# 2           0             0       Brentford    Arsenal        L
# 3           0             0          Wolves    Arsenal        L
# 4           0             1         Watford    Arsenal        L
# ..        ...           ...             ...        ...      ...
# 699         0             0       Brentford     Wolves        D
# 700         1             1        Brighton     Wolves        W
# 701         1             1         Arsenal     Wolves        W
# 702         0             0         Everton     Wolves        L
# 703         1             0  Manchester Utd     Wolves        W
#
# [704 rows x 11 columns]

# %%
merged[merged.TEAM_x=='Arsenal'].sort_values(by = 'DATE')
# Out:
#     actual_x  prediction_x        DATE   TEAM_x       OPPONENT_x RESULT_x  \
# 0          0             0  2022-01-23  Arsenal          Burnley        D
# 1          1             0  2022-02-10  Arsenal           Wolves        W
# 2          1             0  2022-02-19  Arsenal        Brentford        W
# 3          1             0  2022-02-24  Arsenal           Wolves        W
# 4          1             1  2022-03-06  Arsenal          Watford        W
# 5          1             1  2022-03-13  Arsenal   Leicester City        W
# 6          0             1  2022-03-16  Arsenal        Liverpool        L
# 7          1             0  2022-03-19  Arsenal      Aston Villa        W
# 8          0             0  2022-04-04  Arsenal   Crystal Palace        L
# 9          0             0  2022-04-09  Arsenal         Brighton        L
# 10         0             0  2022-04-16  Arsenal      Southampton        L
# 11         1             0  2022-04-20  Arsenal          Chelsea        W
# 12         1             0  2022-04-23  Arsenal   Manchester Utd        W
# 13         1             0  2022-05-01  Arsenal         West Ham        W
# 14         1             0  2022-05-08  Arsenal     Leeds United        W
# 15         0             1  2022-05-12  Arsenal        Tottenham        L
# 16         0             0  2022-05-16  Arsenal    Newcastle Utd        L
# 17         1             0  2022-05-22  Arsenal          Everton        W
# 18         1             0  2022-08-05  Arsenal   Crystal Palace        W
# 19         1             0  2022-08-13  Arsenal   Leicester City        W
# 20         1             0  2022-08-27  Arsenal           Fulham        W
# 21         1             1  2022-08-31  Arsenal      Aston Villa        W
# 22         0             1  2022-09-04  Arsenal   Manchester Utd        L
# 23         1             1  2022-09-18  Arsenal        Brentford        W
# 24         1             1  2022-10-01  Arsenal        Tottenham        W
# 25         1             0  2022-10-09  Arsenal        Liverpool        W
# 26         1             1  2022-10-16  Arsenal     Leeds United        W
# 27         0             1  2022-10-23  Arsenal      Southampton        D
# 28         1             0  2022-10-30  Arsenal  Nott'ham Forest        W
# 29         1             1  2022-11-06  Arsenal          Chelsea        W
# 30         1             1  2022-11-12  Arsenal           Wolves        W
# 31         1             1  2022-12-26  Arsenal         West Ham        W
# 32         1             0  2022-12-31  Arsenal         Brighton        W
#
#     actual_y  prediction_y           TEAM_y OPPONENT_y RESULT_y
# 0          0             0          Burnley    Arsenal        D
# 1          0             0           Wolves    Arsenal        L
# 2          0             0        Brentford    Arsenal        L
# 3          0             0           Wolves    Arsenal        L
# 4          0             1          Watford    Arsenal        L
# 5          0             1   Leicester City    Arsenal        L
# 6          1             1        Liverpool    Arsenal        W
# 7          0             1      Aston Villa    Arsenal        L
# 8          1             0   Crystal Palace    Arsenal        W
# 9          1             1         Brighton    Arsenal        W
# 10         1             0      Southampton    Arsenal        W
# 11         0             1          Chelsea    Arsenal        L
# 12         0             0   Manchester Utd    Arsenal        L
# 13         0             0         West Ham    Arsenal        L
# 14         0             0     Leeds United    Arsenal        L
# 15         1             0        Tottenham    Arsenal        W
# 16         1             0    Newcastle Utd    Arsenal        W
# 17         0             0          Everton    Arsenal        L
# 18         0             0   Crystal Palace    Arsenal        L
# 19         0             0   Leicester City    Arsenal        L
# 20         0             0           Fulham    Arsenal        L
# 21         0             0      Aston Villa    Arsenal        L
# 22         1             0   Manchester Utd    Arsenal        W
# 23         0             0        Brentford    Arsenal        L
# 24         0             1        Tottenham    Arsenal        L
# 25         0             1        Liverpool    Arsenal        L
# 26         0             0     Leeds United    Arsenal        L
# 27         0             0      Southampton    Arsenal        D
# 28         0             0  Nott'ham Forest    Arsenal        L
# 29         0             0          Chelsea    Arsenal        L
# 30         0             0           Wolves    Arsenal        L
# 31         0             0         West Ham    Arsenal        L
# 32         0             0         Brighton    Arsenal        L

# %%
combined2, precision2 = make_predictions (PL_rolling[(PL_rolling.DATE > '2021-08-01') & (PL_rolling.DATE < '2023-01-01')], predictors + new_cols, target = 'TARGET2')
combined2 = combined2.merge(PL_rolling[['DATE', 'TEAM', 'OPPONENT', 'RESULT']], left_index = True, right_index = True)
precision2
# Out:
# 0.4289161560176194

# %%
merged2 = combined2.merge(combined2, left_on = ['DATE', "TEAM"], right_on = ['DATE', 'OPPONENT'])
merged2
# Out:
#      actual_x  prediction_x        DATE   TEAM_x      OPPONENT_x RESULT_x  \
# 0           1             2  2022-01-23  Arsenal         Burnley        D
# 1           2             0  2022-02-10  Arsenal          Wolves        W
# 2           2             2  2022-02-19  Arsenal       Brentford        W
# 3           2             0  2022-02-24  Arsenal          Wolves        W
# 4           2             2  2022-03-06  Arsenal         Watford        W
# ..        ...           ...         ...      ...             ...      ...
# 699         1             0  2022-10-29   Wolves       Brentford        D
# 700         0             2  2022-11-05   Wolves        Brighton        L
# 701         0             0  2022-11-12   Wolves         Arsenal        L
# 702         2             1  2022-12-26   Wolves         Everton        W
# 703         0             2  2022-12-31   Wolves  Manchester Utd        L
#
#      actual_y  prediction_y          TEAM_y OPPONENT_y RESULT_y
# 0           1             0         Burnley    Arsenal        D
# 1           0             0          Wolves    Arsenal        L
# 2           0             0       Brentford    Arsenal        L
# 3           0             0          Wolves    Arsenal        L
# 4           0             2         Watford    Arsenal        L
# ..        ...           ...             ...        ...      ...
# 699         1             0       Brentford     Wolves        D
# 700         2             2        Brighton     Wolves        W
# 701         2             2         Arsenal     Wolves        W
# 702         0             0         Everton     Wolves        L
# 703         2             0  Manchester Utd     Wolves        W
#
# [704 rows x 11 columns]

# %%
merged2.actual_x.value_counts()
# Out:
# actual_x
# 2    277
# 0    277
# 1    150
# Name: count, dtype: int64

# %%
pd.crosstab(index = combined2['actual'], columns = combined2['prediction'])
# Out:
# prediction    0   1    2
# actual
# 0           157  44   78
# 1            66  24   61
# 2           115  30  135

# %%
pd.crosstab(index = combined['actual'], columns = combined['prediction'])
# Out:
# prediction    0   1
# actual
# 0           356  74
# 1           205  75
